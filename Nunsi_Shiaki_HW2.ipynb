# %%
import pandas as pd

# %%
house_data = pd.read_csv("kc_house_data.csv", index_col='id')

# %% [markdown]
# # Q1.0

# %%
house_data.head(10)
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000   221900.0         3       1.00         1180
# 6414100192  20141209T000000   538000.0         3       2.25         2570
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# 1321400060  20140627T000000   257500.0         3       2.25         1715
# 2008000270  20150115T000000   291850.0         3       1.50         1060
# 2414600126  20150415T000000   229500.0         3       1.00         1780
# 3793500160  20150312T000000   323000.0         3       2.50         1890
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %% [markdown]
# # Q1.1

# %%
house_data.loc[7237550310,'price']
# Out:
# 1225000.0

# %% [markdown]
# # Q1.2

# %%
house_data.loc[2414600126,'date']
# Out:
# '20150415T000000'

# %% [markdown]
# # Q1.3

# %%
house_data.tail(10)
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 7852140040  20140825T000000   507250.0         3       2.50         2270
# 9834201367  20150126T000000   429000.0         3       2.00         1490
# 3448900210  20141014T000000   610685.0         4       2.50         2520
# 7936000429  20150326T000000  1007500.0         4       3.50         3510
# 2997800021  20150219T000000   475000.0         3       2.50         1310
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %% [markdown]
# # Q1.4

# %%
house_data.loc[[2997800021],['floors']]
# Out:
#             floors
# id
# 2997800021     2.0

# %% [markdown]
# # Q1.5

# %%
house_data.loc[[263000018],['price']]
# Out:
#               price
# id
# 263000018  360000.0

# %% [markdown]
# # Q1.6

# %%
len(house_data)
# Out:
# 21613

# %% [markdown]
# # Q1.7

# %%
len(house_data.columns)
# Out:
# 20

# %% [markdown]
# # Q1.8

# %%
house_data.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# # Q2.0

# %%
house_data.nunique()
# Out:
# date              372
# price            4028
# bedrooms           13
# bathrooms          30
# sqft_living      1038
# sqft_lot         9782
# floors              6
# waterfront          2
# view                5
# condition           5
# grade              12
# sqft_above        946
# sqft_basement     306
# yr_built          116
# yr_renovated       70
# zipcode            70
# lat              5034
# long              752
# sqft_living15     777
# sqft_lot15       8689
# dtype: int64

# %% [markdown]
# # Q2.1

# %%
house_data['condition'].unique()
# Out:
# array([3, 5, 4, 1, 2], dtype=int64)

# %% [markdown]
# # Q2.2

# %%
house_data['yr_renovated'].nunique()
# Out:
# 70

# %% [markdown]
# # Q2.3

# %%
house_data['long'].nunique()
# Out:
# 752

# %% [markdown]
# # Q2.4

# %%
house_data.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# # Q3.0

# %%
house_data.iloc[314]['bathrooms']
# Out:
# 3.25

# %% [markdown]
# # Q3.1

# %%
house_data.iloc[2718]['grade']
# Out:
# 7

# %% [markdown]
# # Q3.2

# %%
house_data.loc[1000102]
# Out:
#                     date     price  bedrooms  bathrooms  sqft_living  \
# id
# 1000102  20140916T000000  280000.0         6        3.0         2400
# 1000102  20150422T000000  300000.0         6        3.0         2400
#
#          sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 1000102      9373     2.0           0     0          3      7        2400
# 1000102      9373     2.0           0     0          3      7        2400
#
#          sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 1000102              0      1991             0    98002  47.3262 -122.214
# 1000102              0      1991             0    98002  47.3262 -122.214
#
#          sqft_living15  sqft_lot15
# id
# 1000102           2060        7316
# 1000102           2060        7316

# %% [markdown]
# # Q3.3

# %%
house_data.loc[[104510440],['yr_built']]
# Out:
#            yr_built
# id
# 104510440      1984

# %% [markdown]
# # Q4.0

# %%
house_data['view'].value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %% [markdown]
# # Q4.1

# %%
house_data['condition'].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %% [markdown]
# # Q4.2

# %%
house_data['bedrooms'].describe()
# Out:
# count    21613.000000
# mean         3.370842
# std          0.930062
# min          0.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: bedrooms, dtype: float64

# %% [markdown]
# # Q4.3

# %%
house_data['sqft_living'].describe()
# Out:
# count    21613.000000
# mean      2079.899736
# std        918.440897
# min        290.000000
# 25%       1427.000000
# 50%       1910.000000
# 75%       2550.000000
# max      13540.000000
# Name: sqft_living, dtype: float64

# %% [markdown]
# # Q4.4

# %%
house_data.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# # Q4.5

# %%
float_columns= house_data.columns[house_data.dtypes== float]

# %%
float_columns
# Out:
# Index(['price', 'bathrooms', 'floors', 'lat', 'long'], dtype='object')

# %% [markdown]
# # Q5.0

# %%
sqft=house_data.loc[house_data['sqft_basement']==1024,'yr_built']
sqft
# Out:
# id
# 4136980090    2006
# Name: yr_built, dtype: int64

# %% [markdown]
# # Q5.1

# %%
price_dol=house_data.loc[house_data['price']==256000]
price_dol
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7211400990  20150303T000000  256000.0         2       1.00          860
# 8100000090  20141111T000000  256000.0         3       2.50         1480
# 7224000315  20140723T000000  256000.0         3       1.00          880
# 9352901085  20150204T000000  256000.0         3       1.00         1290
# 4058801230  20150305T000000  256000.0         4       1.75         1270
# 8001100030  20150102T000000  256000.0         3       2.50         1570
# 873900240   20140702T000000  256000.0         4       2.50         2050
# 603001045   20150429T000000  256000.0         3       1.00          950
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7211400990      5000     1.0           0     0          3      6         860
# 8100000090      7200     2.0           0     0          5      7        1480
# 7224000315      5375     1.0           0     0          4      5         880
# ...

# %% [markdown]
# # Q5.2

# %%
price_house=house_data.loc[(house_data['bathrooms']==5) & (house_data['yr_built']==1998) & (house_data['grade']== 10),'price']
price_house
# Out:
# id
# 2322069010    1180000.0
# Name: price, dtype: float64

# %% [markdown]
# # Q5.3

# %%
houses=house_data.loc[(house_data['bedrooms']==6) & (house_data['sqft_living']<2000)]
houses
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 6190701146  20150415T000000  520500.0         6       2.50         1880
# 2724069117  20141114T000000  380000.0         6       2.00         1870
# 9276202190  20140808T000000  545000.0         6       1.75         1820
# 1823049202  20140610T000000  175000.0         6       1.50         1930
# 1823049202  20150107T000000  326000.0         6       1.50         1930
# 809000945   20150106T000000  563000.0         6       1.00         1730
# 7227800110  20150409T000000  315000.0         6       2.00         1750
# 1443500305  20141013T000000  194990.0         6       2.50         1560
# 862000020   20150206T000000  800000.0         6       1.00         1430
# 3885808035  20150316T000000  619500.0         6       1.50         1680
# 2568300045  20140625T000000  305000.0         6       2.00         1900
# 2568300045  20150319T000000  649950.0         6       2.00         1900
# ...

# %% [markdown]
# # Q5.4

# %%
houses=house_data.loc[(house_data['grade']>9),'bathrooms'].mean()
houses
# Out:
# 3.197432762836186

# %% [markdown]
# # Q5.5

# %%
least_price= house_data.loc[(house_data['yr_built']>=1991)& (house_data['yr_built']<= 2000),'price'].min()
least_price
# Out:
# 154000.0

# %% [markdown]
# # Q6.0

# %%
house_data['sqft_tot_area']= house_data['sqft_living'] + house_data['sqft_lot'] + house_data['sqft_above'] + house_data['sqft_basement'] + house_data['sqft_living15'] + house_data['sqft_lot15'] 
house_data
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  ...  sqft_above  \
# ...

# %% [markdown]
# # Q6.1

# %%
house_data['sqm_tot_area']= house_data['sqft_tot_area'] * 0.3048
house_data
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# ...

# %% [markdown]
# # Q6.2

# %%
house_data['sqm_aver_floor_area']= house_data['sqm_tot_area'] / house_data['floors']
house_data
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  ...  yr_built  \
# ...

# %% [markdown]
# # Q6.3

# %%
high_class=(house_data['grade']>=9) & (house_data['condition']>=4) 
high_class
# Out:
# id
# 7129300520    False
# 6414100192    False
# 5631500400    False
# 2487200875    False
# 1954400510    False
#               ...
# 263000018     False
# 6600060120    False
# 1523300141    False
# 291310100     False
# 1523300157    False
# Length: 21613, dtype: bool
